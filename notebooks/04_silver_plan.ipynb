# %% [markdown]
# # Plan Silver
# Consulta qué periodos Bronze READY están pendientes de curación, sin transformar datos.

# %%
from pathlib import Path
from tlc_data_platform.core.settings import load_config, resolve_silver_selection
from tlc_data_platform.orchestration.silver_pipeline import plan_silver_pipeline

config = load_config(Path("../config"))
selection = resolve_silver_selection(
    config,
    mode="silver-plan",
    services=["yellow", "green", "fhv", "fhvhv"],
    start_year=2026,
    end_year=2026,
    months=[1],
)
# result = plan_silver_pipeline(config, selection)
# result.to_dict()
