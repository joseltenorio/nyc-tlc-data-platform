# %% [markdown]
# # Plan Bronze
# Calcula cobertura y volumen. Requiere acceso a TLC; MongoDB es opcional para contar procesados.

# %%
from pathlib import Path
from tlc_data_platform.core.settings import load_config, resolve_selection
from tlc_data_platform.orchestration.bronze_pipeline import plan_bronze_pipeline

config = load_config(Path("../config"))
selection = resolve_selection(config, mode="plan", services=["yellow"], start_year=2026, end_year=2026, months=[1])
# result = plan_bronze_pipeline(config, selection)
# result.to_dict()
