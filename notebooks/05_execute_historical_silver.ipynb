# %% [markdown]
# # Ejecución histórica Silver 2019–2025
# Transforma los archivos históricos que Bronze haya registrado como READY. La llamada queda comentada para evitar una ejecución accidental.

# %%
from pathlib import Path
from tlc_data_platform.core.settings import load_config, resolve_silver_selection
from tlc_data_platform.orchestration.silver_pipeline import run_silver_pipeline

config = load_config(Path("../config"))
selection = resolve_silver_selection(config, mode="silver-historical")
# result = run_silver_pipeline(
#     config,
#     selection,
#     execution_type="historical",
# )
# result.to_dict()
