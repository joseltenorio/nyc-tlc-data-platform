# %% [markdown]
# # Validación del entorno Bronze
# Comprueba imports y configuración sin descargar datos.

# %%
from pathlib import Path
from tlc_data_platform.core.settings import load_config

config = load_config(Path("../config"))
print(config.project)
print(config.enabled_services())
print(config.silver.storage.silver_root)
print(config.silver.execution.build_master)
