# %% [markdown]
# # Ejecución histórica 2019–2025
# La celda de ejecución queda comentada para evitar una descarga accidental.

# %%
from pathlib import Path
from tlc_data_platform.core.settings import load_config, resolve_selection
from tlc_data_platform.orchestration.bronze_pipeline import run_bronze_pipeline

config = load_config(Path("../config"))
selection = resolve_selection(config, mode="historical")
# result = run_bronze_pipeline(config, selection, execution_type="historical")
# result.to_dict()
