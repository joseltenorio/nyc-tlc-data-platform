# %% [markdown]
# # Ejecución incremental Silver 2026
# Procesa únicamente los meses de 2026 que ya terminaron correctamente en Bronze.

# %%
from pathlib import Path
from tlc_data_platform.core.settings import load_config, resolve_silver_selection
from tlc_data_platform.orchestration.silver_pipeline import run_silver_pipeline

config = load_config(Path("../config"))
selection = resolve_silver_selection(config, mode="silver-incremental")
# result = run_silver_pipeline(
#     config,
#     selection,
#     execution_type="incremental",
# )
# result.to_dict()
