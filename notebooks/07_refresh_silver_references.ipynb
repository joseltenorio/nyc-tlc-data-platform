# %% [markdown]
# # Actualización de referencias Silver
# Descarga Taxi Zone Lookup y Current Bases, conserva una copia inmutable en Bronze y publica la versión normalizada en Silver.

# %%
from pathlib import Path
from tlc_data_platform.core.settings import load_config
from tlc_data_platform.orchestration.silver_pipeline import refresh_silver_references

config = load_config(Path("../config"))
# result = refresh_silver_references(config)
# result.to_dict()
