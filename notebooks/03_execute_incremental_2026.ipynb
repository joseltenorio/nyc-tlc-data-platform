# %% [markdown]
# # Ejecución incremental 2026
# Procesa únicamente los meses ya publicados.

# %%
from pathlib import Path
from tlc_data_platform.core.settings import load_config, resolve_selection
from tlc_data_platform.orchestration.bronze_pipeline import run_bronze_pipeline

config = load_config(Path("../config"))
selection = resolve_selection(config, mode="incremental")
# result = run_bronze_pipeline(config, selection, execution_type="incremental")
# result.to_dict()
